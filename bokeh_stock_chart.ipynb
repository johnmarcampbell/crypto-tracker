# %%
from iexfinance import get_historical_data
from datetime import datetime, timedelta
from charts import get_product_data, make_rate_plot, get_stock_data
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e3b1ad69-c4b5-4ad0-a382-80436c3c8e05">Loading BokehJS ...</span>
#     </div>

# %%
data = get_stock_data('AAPL')

# end = datetime.utcnow()
# start = end - timedelta(days=365)

# df = get_historical_data("GOOG", start=start, end=end, output_format='pandas')
# df.reset_index(level=0, inplace=True)
# df.rename(columns={'date': 'time'}, inplace=True)
# f = lambda x: int(datetime.strptime(x, '%Y-%m-%d').strftime('%s'))
# df['time'] = df['time'].apply(f)
# df['time'] = df['time'] * 1000

# %%
fig = make_rate_plot(data)
show(fig)
# Out:
#   <div class="bk-root" id="2e76a62e-61ce-415f-a5af-26b2b2e85845"></div>
